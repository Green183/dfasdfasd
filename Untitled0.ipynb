# %% [markdown]
# <a href="https://colab.research.google.com/github/Green183/dfasdfasd/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wearipedia
# !pip install openpyxl
# !pip uninstall -y seaborn
# !pip install seaborn==0.11.1
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
# WARNING: typer 0.17.3 does not provide the extra 'all'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.9/148.9 kB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.7/65.7 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 237.5/237.5 kB 15.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.7/84.7 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.7/99.7 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 26.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 36.8 MB/s eta 0:00:00
# ...

# %%
import os
import pandas as pd
import wearipedia
import matplotlib.pyplot as plt
import datetime
from scipy import stats
from sklearn.covariance import EllipticEnvelope
import copy
import seaborn as sns
from matplotlib import font_manager as fm
from matplotlib import lines as mlines
from scipy.ndimage import gaussian_filter
import matplotlib.dates as mdates
import numpy as np
import json
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1504973426.py in <cell line: 0>()
#       7 from sklearn.covariance import EllipticEnvelope
#       8 import copy
# ----> 9 import seaborn as sns
#      10 from matplotlib import font_manager as fm
#      11 from matplotlib import lines as mlines
#
# /usr/local/lib/python3.12/dist-packages/seaborn/__init__.py in <module>
#       7 from .categorical import *  # noqa: F401,F403
#       8 from .distributions import *  # noqa: F401,F403
# ----> 9 from .matrix import *  # noqa: F401,F403
#      10 from .miscplot import *  # noqa: F401,F403
#      11 from .axisgrid import *  # noqa: F401,F403
#
# /usr/local/lib/python3.12/dist-packages/seaborn/matrix.py in <module>
#      11 from scipy.cluster import hierarchy
#      12
# ---> 13 from . import cm
#      14 from .axisgrid import Grid
# ...

# %%
# !pip install matplotlib==3.5.1 seaborn==0.11.2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 55.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.8/292.8 kB 21.5 MB/s eta 0:00:00
# ...
#   Created wheel for matplotlib: filename=matplotlib-3.5.1-cp312-cp312-linux_x86_64.whl size=11111239 sha256=698e03b13d55562844cd4c599020a5122bb5efc96f7a1742cc50936d50c803de
#   Stored in directory: /root/.cache/pip/wheels/39/4d/74/53c3ca11345064db1a2e2c6b780aed292a0b646d4038ad5f9e
# Successfully built matplotlib
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.11.1
#     Uninstalling seaborn-0.11.1:
#       Successfully uninstalled seaborn-0.11.1
# ...

# %%
import os
import re               # <- dodaj tę linię
import pandas as pd
import wearipedia
import matplotlib.pyplot as plt
import datetime
from scipy import stats
from sklearn.covariance import EllipticEnvelope
import copy
import seaborn as sns
from matplotlib import font_manager as fm
from matplotlib import lines as mlines
from scipy.ndimage import gaussian_filter
import matplotlib.dates as mdates
import numpy as np
import json

# %%
email_address = "oleksa.dawid@gmail.com"  # Twój login Cronometer
password = "5PHUDewx8cFQsVH"                # Twoje hasło Cronometer

# %%
start_date = '2022-03-01'  # data początkowa w formacie yyyy-mm-dd
end_date = '2025-09-12'    # data końcowa w formacie yyyy-mm-dd
synthetic = False            # jeśli chcesz użyć danych testowych, ustaw True
device = wearipedia.get_device("cronometer/cronometer")

if not synthetic:
    device.authenticate({"username": email_address, "password": password})

params = {"start_date": start_date, "end_date": end_date}
# Out:
# Authentication successful

# %%
import wearipedia.devices.cronometer.cronometer_fetch as cf
import re
import pandas as pd # Import pandas here
cf.re = re  # <- inject the re module into wearipedia
cf.pd = pd  # <- inject the pandas module into wearipedia

# %%
import wearipedia.devices.cronometer.cronometer_fetch as cf
import pandas as pd
import io

cf.pd = pd
cf.io = io

# %%
dailySummary = device.get_data("dailySummary", params=params)
pd.DataFrame(dailySummary).head()
# Out:
#          Date  Energy (kcal)  Alcohol (g)  Caffeine (mg)  Water (g)  \
# 0  2023-04-06            NaN          NaN            NaN        NaN
# 1  2023-04-07        1522.24         0.00           0.00     504.74
# 2  2023-04-08        2244.80         0.00           0.00    1357.81
# 3  2023-04-09        2024.35         0.20           9.05     488.99
# 4  2023-04-10        2034.67        15.54          14.40    1395.46
#
#    B1 (Thiamine) (mg)  B2 (Riboflavin) (mg)  B3 (Niacin) (mg)  \
# 0                 NaN                   NaN               NaN
# 1                0.51                 97.32             16.52
# 2                1.83                  2.00             31.21
# 3                1.13                  0.86             15.74
# 4                2.31                 97.34             19.95
#
#    B5 (Pantothenic Acid) (mg)  B6 (Pyridoxine) (mg)  ...  Leucine (g)  \
# 0                         NaN                   NaN  ...          NaN
# ...

# %%
servings = device.get_data("servings", params=params)
pd.DataFrame(servings).head()
# Out:
#           Day          Group  \
# 0  2023-04-07  Uncategorized
# 1  2023-04-07  Uncategorized
# 2  2023-04-07  Uncategorized
# 3  2023-04-07  Uncategorized
# 4  2023-04-07  Uncategorized
#
#                                            Food Name    Amount  Energy (kcal)  \
# 0                                        Linseed Oil  2.00 tsp           80.3
# 1                                            Walnuts   20.00 g          135.8
# 2         Turkey Breast, Skin Removed Before Cooking  100.00 g          147.0
# 3  Rice, White, Long-Grain, Regular, Enriched, Co...  100.00 g          130.0
# 4                            Pepper, Sweet, Red, Raw   50.00 g           13.5
#
#    Alcohol (g)  Caffeine (mg)  Water (g)  B1 (Thiamine) (mg)  \
# 0          0.0            0.0       0.01                0.00
# 1          0.0            0.0       0.63                0.05
# 2          0.0            0.0      67.88                0.04
# 3          0.0            0.0      68.44                0.16
# ...

# %%
exercises = device.get_data("exercises", params=params)
pd.DataFrame(exercises).head()
# Out:
#           Day          Group          Exercise    Minutes  Calories Burned
# 0  2023-04-06  Uncategorized     Walk (Fitbit)  21.350000           -117.0
# 1  2023-04-06  Uncategorized   Fitbit Activity  22.000000          -1002.0
# 2  2023-04-07  Uncategorized   Fitbit Activity   0.000000           -676.0
# 3  2023-04-08  Uncategorized   Fitbit Activity  47.000000           -376.0
# 4  2023-04-08  Uncategorized  Weights (Fitbit)  50.466667           -335.0

# %%
biometrics = device.get_data("biometrics", params=params)
pd.DataFrame(biometrics).head()
# Out:
#           Day          Group               Metric    Unit    Amount
# 0  2023-04-06  Uncategorized       Sleep (Fitbit)  hr:min   6.70000
# 1  2023-04-06  Uncategorized  Heart Rate (Fitbit)     bpm  55.00000
# 2  2023-04-07  Uncategorized       Sleep (Fitbit)  hr:min   7.78333
# 3  2023-04-07  Uncategorized  Heart Rate (Fitbit)     bpm  55.00000
# 4  2023-04-08  Uncategorized       Sleep (Fitbit)  hr:min   7.78333

# %%
# Zamieniamy dane na DataFrame
dailySummary_df = pd.DataFrame.from_dict(dailySummary)
servings_df = pd.DataFrame.from_dict(servings)
exercises_df = pd.DataFrame.from_dict(exercises)
biometrics_df = pd.DataFrame.from_dict(biometrics)

# Eksport do plików CSV
dailySummary_df.to_csv('dailySummary.csv', index=False)
servings_df.to_csv('servings.csv', index=False)
exercises_df.to_csv('exercises.csv', index=False)
biometrics_df.to_csv('biometrics.csv', index=False)

# %%
# !pip install --upgrade gspread gspread_dataframe

# %%
from google.colab import files
uploaded = files.upload()  # wybierz pobrany JSON
# Out:
#      <input type="file" id="files-d3c3de34-a01d-4943-af84-46c229eaae71" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d3c3de34-a01d-4943-af84-46c229eaae71">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files

# Wgraj plik JSON z dysku lokalnego
uploaded = files.upload()  # wybierz plik cronometer-sa.json

# Sprawdź, że plik jest w środowisku
import os
os.listdir()
# Out:
#      <input type="file" id="files-1dd594f6-3718-4f68-bf34-769d5e728fe9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1dd594f6-3718-4f68-bf34-769d5e728fe9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import gspread # Add this line
gc = gspread.service_account(filename="cronometer-sa.json")

# %%
SPREADSHEET_ID = "1hp0C4x5JbGhfoCYxZ5zorf7lKHYnZEbLo_CRKOD4Ucs"
sh = gc.open_by_key(SPREADSHEET_ID)

# %%
from gspread_dataframe import set_with_dataframe

def save_to_sheet(df, sheet_name):
    try:
        worksheet = sh.worksheet(sheet_name)  # jeśli arkusz istnieje
    except gspread.WorksheetNotFound:
        worksheet = sh.add_worksheet(title=sheet_name, rows=1000, cols=50)  # jeśli nie
    set_with_dataframe(worksheet, df)

# %%
import pandas as pd

# Konwertujemy listę na DataFrame
dailySummary_df = pd.DataFrame(dailySummary)

# Teraz zapis do arkusza
save_to_sheet(dailySummary_df, "DailySummary")
